# %%
import pandas as pd

csv1 = pd.read_csv('/Users/rasmuskopperudriis/Coding/work_folder/runfolder/INF055_results/mutation/app_merged_mutation_vaccine.csv')
csv2 = pd.read_csv('/Users/rasmuskopperudriis/Coding/work_folder/runfolder/INF055_summary.csv')


csv1_HA = csv1[csv1['Ref_Name'].str.contains('HA')]
csv1_NA = csv1[csv1['Ref_Name'].str.contains('NA')]

pivoted_df1_HA = csv1_HA.groupby('sample')['Differences'].apply(';'.join).reset_index().rename(columns={'Differences': 'Vaccine Mutations HA'})
pivoted_df1_NA = csv1_NA.groupby('sample')['Differences'].apply(';'.join).reset_index().rename(columns={'Differences': 'Vaccine Mutations NA'})

merged_df = pd.merge(pivoted_df1_HA, pivoted_df1_NA, on='sample', how='outer')
merged_df = merged_df.rename(columns={'sample': 'Sample'})



final_merge = pd.merge(csv2, merged_df, on='Sample', how='outer')

final_merge.head()




#pivoted_csv1 = csv1.groupby(['sample','Ref_Name'])['Differences'].apply(';'.join).reset_index()
#pivoted_csv1.head()
# Out:
#            SequenceID Run Name       Sample     Subtype Fluserver Mutations  \
# 0     INF055_1Pos55_N   INF055     1Pos55_N        H1N1            NO MATCH
# 1  INF055_252309858_N   INF055  252309858_N        H1N1            NO MATCH
# 2     INF055_2Pos55_N   INF055     2Pos55_N  B_Victoria            NO MATCH
#
#            Clade  Neuraminidase 1 823 Thymine Ratio  \
# 0           6B.1                           0.004537
# 1  6B.1A.5a.2a.1                           0.005477
# 2            V1A                                NaN
#
#    Neuraminidase 1 823 Cytosine Ratio  Average Depth A H1 HA  \
# 0                            0.991933                5239.08
# 1                            0.992175                 966.72
# 2                                 NaN                    NaN
#
#    Average Depth A N1 NA  ...            Script Timestamp  \
# 0                9120.44  ...  2024-01-03 10:24:25.059323
# 1                1280.00  ...  2024-01-03 10:24:25.059323
# 2                    NaN  ...  2024-01-03 10:24:25.059323
#
#    Sample Approval Status  Quality        Script Version  Average Depth HA  \
# 0                     NaN     High  INFLUENZA_V1_VERSION           5239.08
# 1                     NaN     High  INFLUENZA_V1_VERSION            966.72
# 2                     NaN     High  INFLUENZA_V1_VERSION           2559.85
#
#    Average Depth NA                                       Mutations HA  \
# 0           9120.44  R74S;D129N;T164S;P183S;I185T;A187D;E189Q;Q223R...
# 1           1280.00  K54Q;T120A;K130N;P137S;A141V;K142R;N156K;L161I...
# 2           3591.01  E48K;K75N;R80K;T121I;N129K;I146V;K165N;P172S;T...
#
#                                         Mutations NA  \
# 0  K51Q;N52S;S74F;R77G;A81V;T188I;K389I;N416D;D44...
# 1  M19T;N50D;N52S;Y66F;N222K;G382E;V448I;V453M;K469N
# 2  S27L;E44K;I45V;T46I;P51S;R65H;K69E;G70E;V71M;L...
#
#                                 Vaccine Mutations HA  \
# 0  Q54K;R74S;D129N;N130K;S137P;R142K;K156N;I161L;...
# 1                             T120A;A141V;K259Q;I45V
# 2  E48K;K75N;R80K;V117I;T121I;T127A;D129K;E136K;L...
#
#                                 Vaccine Mutations NA
# 0  T19M;D50N;K51Q;F66Y;S74F;R77G;A81V;T188I;K222N...
# 1                                              V448I
# 2  S27L;Q42P;E44K;I45V;T46I;P51S;R65H;K69E;G70E;A...
#
# [3 rows x 64 columns]
